# %%
import pandas as pd
import numpy as np

# %%
file_path = 'data/cosmicclassifierTest.csv'
df = pd.read_csv(file_path)
df.head(5)
# Out:
#    Atmospheric Density  Surface Temperature   Gravity  Water Content  \
# 0            -1.303074             2.932540 -0.168043      -1.220249
# 1             0.081124            -3.747390 -0.598897       1.563487
# 2            -3.709952            -1.689588  0.259499       1.020046
# 3             4.838804             0.442909  0.995312      -0.385272
# 4             0.742217             2.802281 -1.144759       2.475840
#
#    Mineral Abundance  Orbital Period  Proximity to Star  \
# 0          -1.942662        0.950473           1.540782
# 1          -0.199953       -1.844926           1.095349
# 2          -2.094565        0.344641          -0.094227
# 3          -0.818065       -1.903998           2.727794
# 4          -0.585959        0.880694          -1.942863
#
#   Magnetic Field Strength Radiation Levels  Atmospheric Composition Index
# 0             Category_13       Category_6                      -0.729809
# ...

# %%
print(df.shape)
print(list(df.columns))
# Out:
# (10000, 10)
# ['Atmospheric Density', 'Surface Temperature', 'Gravity', 'Water Content', 'Mineral Abundance', 'Orbital Period', 'Proximity to Star', 'Magnetic Field Strength', 'Radiation Levels', 'Atmospheric Composition Index']

# %%
missing_values = df.isna().sum()
print("\nMissing values per column:")
print(missing_values)
# Out:
# Missing values per column:
# Atmospheric Density              0
# Surface Temperature              0
# Gravity                          0
# Water Content                    0
# Mineral Abundance                0
# Orbital Period                   0
# Proximity to Star                0
# Magnetic Field Strength          0
# Radiation Levels                 0
# Atmospheric Composition Index    0
# dtype: int64

# %%
print("\nDescriptive statistics for numeric columns:")
df.describe()
# Out:
# Descriptive statistics for numeric columns:
#        Atmospheric Density  Surface Temperature       Gravity  Water Content  \
# count         10000.000000         10000.000000  10000.000000   10000.000000
# mean              0.074543             0.028896     -0.081860       0.008577
# std               2.297061             1.992407      1.782432       1.704504
# min              -4.227332            -5.604589     -5.197671      -5.592158
# 25%              -1.491899            -1.443051     -1.341715      -1.201182
# 50%              -0.131723            -0.260230     -0.055050       0.019245
# 75%               1.414674             1.595845      1.161693       1.055115
# max               9.354729             5.070067      5.201851       6.043354
#
#        Mineral Abundance  Orbital Period  Proximity to Star  \
# count       10000.000000    10000.000000       10000.000000
# mean            0.097151       -0.026615           0.088995
# ...
